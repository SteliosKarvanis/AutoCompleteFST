# %% [markdown]
# # Test Notebook

# %% [markdown]
# ## Code

# %%
import random
import string
import subprocess
import os

# %%
os.chdir("..")

# %% [markdown]
# Read the dictionary

# %%
words = []
with open("data/american_english_sorted.txt", 'r') as f:
    for word in f.readlines():
        words.append(word.replace('\n', ''))

# %% [markdown]
# Generate random prefixes

# %%
num_samples = 1000

# %%
prefixes = []
for word in random.sample(words, num_samples):
    while(len(word) < 2):
        word = random.choice(words)
    rand_int = random.randint(1, len(word)-1)
    prefix = word[:rand_int]
    prefixes.append(prefix)

# %% [markdown]
# Save prefix examples to file

# %%
os.makedirs("tmp", exist_ok=True)
with open("tmp/examples.txt", "w") as f:
    for x in prefixes:
        f.write(x)
        f.write("\n")

# %%
prefixes[:5]
# Out:
# ['abus', 'purgatory', 'lif', 'Marpl', 'emotio']

# %% [markdown]
# To generate random prefixes with a fix length:

# %%
def get_random(prefix_len: int):
    while True:
        word = random.choice(words)
        if len(word) >= prefix_len:
            break
    return word[:prefix_len]

def get_result(prefix: str):
    return [x for x in words if x.startswith(prefix)]

# %%
prefix = get_random(prefix_len=4)
results = get_result(prefix)
print(prefix) 
print(results)
# Out:
# atta
# ['attach', 'attached', 'attaching', 'attachment', "attachment's", 'attachments', 'attack', "attack's", 'attacked', 'attacker', "attacker's", 'attackers', 'attacking', 'attacks', 'attain', 'attainable', 'attained', 'attaining', 'attainment', "attainment's", 'attainments', 'attains', 'attar', "attar's"]

# %%
def gen_results():
    if os.path.exists("output_files/output_autocomplete.txt"):
        os.remove("output_files/output_autocomplete.txt")
    os.chdir("bin")
    program_path = './autocomplete'
    arguments = ["../tmp/examples.txt"]
    subprocess.run([program_path] + arguments, text=True, capture_output=True)
    os.chdir("..")

def get_cpp_results():
    results = []
    with open("output_files/output_autocomplete.txt", 'r') as f:
        for line in f.readlines():
            line = line.replace("\n", "").strip()
            if line == ']':
                yield results
                results = []
            if line and not line == '[' and not line == ']':
                results.append(line)
            

def gen_expected_results():
    with open("tmp/examples.txt", 'r') as f:
        for line in f.readlines():
            line = line.replace('\n', '').strip()
            yield [x for x in words if x.startswith(line)]

def check_autocomplete():
    keys = []
    with open("tmp/examples.txt", 'r') as f:
        for line in f.readlines():
            line = line.replace('\n', '').strip()
            keys.append(line)
        
    for key, l1, l2 in zip(keys, get_cpp_results(), gen_expected_results()):
        if l1 != l2:
            print(f"Failed for {key}")
            print([x for x in l1 if x not in l2])
            print([x for x in l2 if x not in l1])
            return False
        else:
            print(f"Checked {key}")

# %%
gen_results()

# %%
check_autocomplete()
# Out:
# Checked abus
# Checked purgatory
# Checked lif
# Checked Marpl
# Checked emotio
# Checked ballpoi
# Checked dru
# Checked vapidness'
# Checked Creole
# Checked franchise
# Checked illustrator'
# Checked aneur
# Checked increa
# Checked serg
# Checked haws
# Checked del
# Checked reparat
# Checked t
# Checked sw
# Checked Gabl
# Checked irra
# Checked coronaviru
# Checked tames
# Checked Potsdam'
# Checked geo
# Checked siblin
# Checked Dawe
# Checked Mar
# Checked disr
# Checked derang
# Checked birc
# Checked I
# Checked unfurle
# Checked entertai
# Checked Cyclo
# Checked pai
# Checked po
# Checked i
# Checked owe
# Checked snivelle
# Checked iter
# Checked Ard
# Checked slowpo
# Checked teletypewri
# Checked blackmail
# Checked Worces
# Checked pre
# Checked flu
# Checked outag
# Checked bonuse
# Checked cen
# Checked inve
# Checked M
# Checked C
# Checked divorci
# Checked adie
# Checked clo
# Checked equato
# Checked en
# Checked proneness'
# Checked de
# Checked needless
# Checked excheq
# Checked vul
# Checked Rutgers
# Checked br
# Checked shrew
# Checked ye
# Checked newe
# Checked retrofitte
# Checked com
# Checked stumbl
# Checked wallo
# Checked blo
# Checked adden
# Checked weatherproof
# Checked analogu
# Checked vi
# Checked w
# Checked Bar
# Checked audit
# Checked impoun
# Checked su
# Checked c
# Checked q
# Checked ti
# Checked gur
# Checked flo
# Checked enact
# Checked courteousn
# Checked Re
# Checked ge
# Checked un
# Checked veer
# Checked oldi
# Checked Pen
# Checked re
# Checked t
# Checked o
# Checked waterm
# Checked levelin
# Checked C
# Checked dr
# Checked Qu
# Checked cobblest
# Checked Re
# Checked Kathie'
# Checked sco
# Checked scol
# Checked ti
# Checked Sa
# Checked Judas
# Checked ski
# Checked broomsti
# Checked d
# Checked tim
# Checked dis
# Checked poll
# Checked a
# Checked declamation'
# Checked N
# Checked fighting
# Checked Bissau
# Checked in
# Checked tra
# Checked costing
# Checked hobbi
# Checked go
# Checked naked
# Checked clic
# Checked pla
# Checked n
# Checked Mena
# Checked Menelau
# Checked shl
# Checked qua
# Checked locksmi
# Checked bitterne
# Checked tw
# Checked osteo
# Checked overwriti
# Checked pa
# Checked malig
# Checked cata
# Checked A
# Checked manifest
# Checked con
# Checked craw
# Checked timberli
# Checked tea
# Checked prov
# Checked fev
# Checked Mar
# Checked Sheraton
# Checked export
# Checked L
# Checked prize
# Checked brot
# Checked pump
# Checked canopyi
# Checked phosphores
# Checked t
# Checked ful
# Checked evolutio
# Checked curvie
# Checked Ma
# Checked r
# Checked verisimilitu
# Checked expiratio
# Checked baller
# Checked q
# Checked blesse
# Checked expectoratio
# Checked Ba
# Checked lo
# Checked Agricola
# Checked vo
# Checked bilge'
# Checked No
# Checked ung
# Checked lo
# Checked staini
# Checked analog
# Checked Schin
# Checked pin
# Checked Jinnah
# Checked rob
# Checked pal
# Checked Chav
# Checked quiet
# Checked rela
# Checked d
# Checked paraplegia
# Checked pr
# Checked charco
# Checked misquot
# Checked discom
# Checked ski
# Checked handym
# Checked deni
# Checked G
# Checked enamo
# Checked hardhearte
# Checked trundl
# Checked Sophocle
# Checked detainment
# Checked cardsha
# Checked beh
# Checked affl
# Checked v
# Checked Sal
# Checked underestimat
# Checked jungl
# Checked lau
# Checked sca
# Checked co
# Checked Pi
# Checked celebratio
# Checked crucifor
# Checked gondo
# Checked Laiu
# Checked c
# Checked dou
# Checked fi
# Checked C
# Checked BIT
# Checked na
# Checked mum
# Checked p
# Checked que
# Checked f
# Checked cloakroo
# Checked A
# Checked toothso
# Checked complaisa
# Checked splo
# Checked flooring
# Checked plu
# Checked wraparoun
# Checked endiv
# Checked Xin
# Checked reappointme
# Checked pella
# Checked Mandelbrot
# Checked Mencius
# Checked a
# Checked cens
# Checked reb
# Checked essen
# Checked demis
# Checked wei
# Checked aliase
# Checked cadr
# Checked Excellenc
# Checked manikin'
# Checked pila
# Checked he
# Checked ro
# Checked Bere
# Checked l
# Checked morti
# Checked misha
# Checked bath
# Checked goble
# Checked G
# Checked hon
# Checked cro
# Checked Confederac
# Checked hija
# Checked c
# Checked a
# Checked levitatio
# Checked bela
# Checked swellhead
# Checked prove
# Checked Rastafari
# Checked teet
# Checked Adirondacks
# Checked murkies
# Checked quaki
# Checked u
# Checked pige
# Checked lo
# Checked Ogd
# Checked Da
# Checked disme
# Checked Tann
# Checked Billy'
# Checked rec
# Checked predicativ
# Checked bubb
# Checked Keit
# Checked ora
# Checked su
# Checked cu
# Checked Kath
# Checked nestlin
# Checked s
# Checked st
# Checked Pleiades
# Checked Enkidu
# Checked Cape
# Checked Berbe
# Checked Glastonbury
# Checked Q
# Checked Cryp
# Checked f
# Checked s
# Checked b
# Checked aus
# Checked of
# Checked E
# Checked oppo
# Checked intert
# Checked j
# Checked Balk
# Checked su
# Checked fresh
# Checked incubus'
# Checked b
# Checked i
# Checked f
# Checked undet
# Checked je
# Checked s
# Checked Abb
# Checked rei
# Checked pinhole
# Checked s
# Checked intrusi
# Checked councilwom
# Checked sheepishness
# Checked God
# Checked ski
# Checked R
# Checked j
# Checked B
# Checked Bor
# Checked tit
# Checked Quixo
# Checked co
# Checked poac
# Checked comp
# Checked mad
# Checked undi
# Checked exp
# Checked Coppola'
# Checked deathle
# Checked cras
# Checked medulla
# Checked in
# Checked ou
# Checked d
# Checked w
# Checked m
# Checked ove
# Checked faste
# Checked felt
# Checked Wa
# Checked ex
# Checked Hoope
# Checked priva
# Checked blin
# Checked monas
# Checked s
# Checked sc
# Checked fall
# Checked inte
# Checked hu
# Checked bra
# Checked to
# Checked Tal
# Checked kamikaz
# Checked or
# Checked Tampa
# Checked Lusaka
# Checked Yak
# Checked Ant
# Checked rev
# Checked clearing
# Checked blus
# Checked ampu
# Checked Muh
# Checked prett
# Checked writi
# Checked beam
# Checked ov
# Checked ta
# Checked b
# Checked inevita
# Checked opio
# Checked Erni
# Checked cach
# Checked swilli
# Checked Br
# Checked old
# Checked sea
# Checked adequ
# Checked sabre'
# Checked exce
# Checked masc
# Checked assertiv
# Checked sh
# Checked bu
# Checked es
# Checked agribusine
# Checked glock
# Checked nob
# Checked absenc
# Checked Ve
# Checked h
# Checked E
# Checked ven
# Checked oil
# Checked re
# Checked rasc
# Checked vitupe
# Checked Kirby
# Checked wo
# Checked cadge
# Checked iro
# Checked PT
# Checked flatto
# Checked taber
# Checked unde
# Checked po
# Checked grandmo
# Checked cr
# Checked re
# Checked p
# Checked stub
# Checked underg
# Checked pilothouse
# Checked Wilfred
# Checked popg
# Checked Alexe
# Checked ru
# Checked Mine
# Checked recruit
# Checked so
# Checked regime
# Checked tor
# Checked Taipei'
# Checked Ca
# Checked overheat
# Checked f
# Checked yak
# Checked dri
# Checked pav
# Checked kno
# Checked R
# Checked mood
# Checked StairMaster'
# Checked ce
# Checked De
# Checked mou
# Checked kick
# Checked bac
# Checked adven
# Checked look
# Checked worthles
# Checked mantelpie
# Checked Apollinair
# Checked je
# Checked code
# Checked fin
# Checked pooch
# Checked pe
# Checked i
# Checked Da
# Checked immu
# Checked senna
# Checked minic
# Checked repug
# Checked Rea
# Checked sweep
# Checked marks
# Checked s
# Checked t
# Checked tyra
# Checked stigma
# Checked g
# Checked retrie
# Checked upsta
# Checked Steub
# Checked waln
# Checked C
# Checked ca
# Checked clic
# Checked fros
# Checked ar
# Checked Bundesba
# Checked ESP'
# Checked wret
# Checked priss
# Checked esthet
# Checked hum
# Checked sh
# Checked crin
# Checked dy
# Checked exhausti
# Checked i
# Checked aphori
# Checked S
# Checked mayo
# Checked bisho
# Checked m
# Checked l
# Checked s
# Checked pig
# Checked idi
# Checked af
# Checked Blo
# Checked unscra
# Checked wingl
# Checked wave
# Checked citi
# Checked adjectiv
# Checked redoubt
# Checked b
# Checked debt
# Checked manicuri
# Checked deli
# Checked ful
# Checked awr
# Checked c
# Checked longshor
# Checked s
# Checked de
# Checked enf
# Checked tabl
# Checked Cla
# Checked ref
# Checked tomb
# Checked impu
# Checked blackball
# Checked synd
# Checked mo
# Checked be
# Checked p
# Checked kest
# Checked grumpi
# Checked Fic
# Checked Uni
# Checked sa
# Checked sup
# Checked Mel
# Checked ba
# Checked salv
# Checked fut
# Checked bribin
# Checked neoclassicis
# Checked chatti
# Checked Vulca
# Checked brood'
# Checked demeani
# Checked d
# Checked regulato
# Checked bide
# Checked cli
# Checked Keller'
# Checked fraterni
# Checked r
# Checked re
# Checked opi
# Checked pola
# Checked alimony
# Checked whorle
# Checked D
# Checked anecd
# Checked b
# Checked he
# Checked linesman'
# Checked gal
# Checked w
# Checked bas
# Checked Os
# Checked cospons
# Checked by
# Checked parit
# Checked strangulat
# Checked apos
# Checked antic
# Checked Dorothe
# Checked flat
# Checked nu
# Checked I
# Checked ben
# Checked unr
# Checked garbagema
# Checked co
# Checked i
# Checked flowerp
# Checked ha
# Checked g
# Checked over
# Checked p
# Checked abstrac
# Checked re
# Checked riffle
# Checked skid
# Checked ad
# Checked sectar
# Checked turquoi
# Checked wristb
# Checked fo
# Checked hyperte
# Checked counten
# Checked pard
# Checked att
# Checked Ver
# Checked sa
# Checked c
# Checked tr
# Checked e
# Checked fas
# Checked S
# Checked accuser
# Checked hybr
# Checked s
# Checked sun
# Checked understudie
# Checked deve
# Checked chrysalise
# Checked Hammer
# Checked fir
# Checked vis
# Checked scatterbrain
# Checked putrefactio
# Checked rudde
# Checked Sui
# Checked com
# Checked spine
# Checked n
# Checked tra
# Checked eagerne
# Checked Da
# Checked la
# Checked misconstructi
# Checked B
# Checked shro
# Checked bandyin
# Checked an
# Checked kn
# Checked jo
# Checked headq
# Checked F
# Checked fortress
# Checked immaturit
# Checked p
# Checked inertness'
# Checked pantsuit
# Checked Canopus'
# Checked roto
# Checked isthmu
# Checked Bur
# Checked hol
# Checked C
# Checked whi
# Checked metron
# Checked tr
# Checked emotio
# Checked bree
# Checked Genet
# Checked hus
# Checked fie
# Checked m
# Checked resis
# Checked bowl
# Checked BAS
# Checked Ausc
# Checked beq
# Checked c
# Checked n
# Checked imperson
# Checked naugh
# Checked V
# Checked C
# Checked stuffin
# Checked observ
# Checked Pie
# Checked perv
# Checked S
# Checked confis
# Checked ya
# Checked rem
# Checked p
# Checked be
# Checked fo
# Checked ta
# Checked fault'
# Checked Oakle
# Checked p
# Checked co
# Checked w
# Checked AN
# Checked wound
# Checked Elizabethtow
# Checked faithless
# Checked harri
# Checked St
# Checked hank
# Checked Vinc
# Checked compo
# Checked lexicogr
# Checked displ
# Checked h
# Checked ge
# Checked ne
# Checked u
# Checked abat
# Checked lapto
# Checked tr
# Checked observance
# Checked beste
# Checked ounce
# Checked cas
# Checked metap
# Checked patc
# Checked br
# Checked in
# Checked cannies
# Checked atmos
# Checked overdre
# Checked pomp
# Checked stopligh
# Checked recapi
# Checked E
# Checked typ
# Checked incorpo
# Checked Dar
# Checked Matlab'
# Checked bowling'
# Checked reb
# Checked syph
# Checked Ro
# Checked competen
# Checked su
# Checked detestation'
# Checked bo
# Checked fill
# Checked over
# Checked inc
# Checked NS
# Checked freightin
# Checked ampl
# Checked He
# Checked distraugh
# Checked sevent
# Checked mi
# Checked son
# Checked do
# Checked exi
# Checked Vladi
# Checked subord
# Checked procurer
# Checked howler'
# Checked analyst'
# Checked cutthroat'
# Checked solic
# Checked adj
# Checked po
# Checked cili
# Checked be
# Checked magnifyi
# Checked cameo'
# Checked id
# Checked ent
# Checked el
# Checked unconscionabl
# Checked dis
# Checked p
# Checked option'
# Checked ins
# Checked aut
# Checked tremble
# Checked upr
# Checked i
# Checked singl
# Checked ele
# Checked Do
# Checked opt
# Checked dairymai
# Checked Beach'
# Checked c
# Checked ni
# Checked reta
# Checked ref
# Checked sta
# Checked whip
# Checked advent
# Checked P
# Checked beat
# Checked persev
# Checked C
# Checked c
# Checked q
# Checked Jez
# Checked q
# Checked Os
# Checked w
# Checked recla
# Checked cage'
# Checked tr
# Checked m
# Checked ep
# Checked dis
# Checked s
# Checked barra
# Checked b
# Checked noncooperat
# Checked dispense
# Checked gra
# Checked elo
# Checked do
# Checked Maracai
# Checked a
# Checked palmies
# Checked newton'
# Checked pred
# Checked ea
# Checked salespeopl
# Checked sp
# Checked carc
# Checked Este
# Checked thi
# Checked sols
# Checked t
# Checked Pyt
# Checked fiel
# Checked interme
# Checked budge
# Checked antiphona
# Checked Luc
# Checked hexe
# Checked El
# Checked teas
# Checked co
# Checked cumula
# Checked boate
# Checked Yb'
# Checked w
# Checked de
# Checked i
# Checked sa
# Checked Wond
# Checked disloc
# Checked motivat
# Checked totterin
# Checked constituti
# Checked Tu
# Checked ap
# Checked marki
# Checked Du
# Checked l
# Checked E
# Checked Casca
# Checked for
# Checked Fried
# Checked visualize
# Checked optician
# Checked om
# Checked capill
# Checked over
# Checked unc
# Checked madras
# Checked insubordin
# Checked declivity'
# Checked d'Estain
# Checked invei
# Checked neurotransmi
# Checked wave
# Checked am
# Checked ar
# Checked wav
# Checked pu
# Checked fl
# Checked gly
# Checked Rena
# Checked h
# Checked abs
# Checked cozine
# Checked Babyl
# Checked tortil
# Checked gero
# Checked cannabi
# Checked Ha
# Checked be
# Checked embodiment'
# Checked nuzzle
# Checked squirrell
# Checked Vishnu'
# Checked t
# Checked dresse
# Checked l
# Checked Darl
# Checked truncat
# Checked firt
# Checked raucou
# Checked t
# Checked heteros
# Checked mo
# Checked fende
# Checked marine
# Checked Na
# Checked cra
# Checked bl
# Checked wedge'
# Checked hostler
# Checked reneg
# Checked motherhoo
# Checked m
# Checked unionizati
# Checked t
# Checked villa'
# Checked fla
# Checked sies
# Checked tyrann
# Checked W
# Checked dash
# Checked assa
# Checked idea
# Checked Mid
# Checked co
# Checked serenit
# Checked K
# Checked nonhazardo
# Checked ve
# Checked maro
# Checked ch
# Checked Kotlin
# Checked sedates
# Checked Keoku
# Checked q
# Checked mo
# Checked cert
# Checked multiple
# Checked dro
# Checked spa
# Checked enve
# Checked valen
# Checked repossess
# Checked coerc
# Checked dis
# Checked fa
# Checked sho
# Checked f
# Checked fl
# Checked plas
# Checked c
# Checked P
# Checked concili
# Checked pe
# Checked h
# Checked te
# Checked ram
# Checked praline
# Checked banya
# Checked war
# Checked P
# Checked bowler
# Checked Chin
# Checked absur
# Checked precipi
# Checked beauti
# Checked O
# Checked flight
# Checked fle
# Checked pugna
# Checked g
# Checked grid
# Checked ES
# Checked ev
# Checked visual
# Checked syn
# Checked cog
# Checked del
# Checked wh
# Checked Annap
# Checked s
# Checked re
# Checked g
# Checked frow
# Checked backb
# Checked Chatte
# Checked Folsom
# Checked V
# Checked ke
# Checked sui
# Checked portcullis
# Checked apostat
# Checked Dion
# Checked h
# Checked multi
# Checked welfa
# Checked Lo
# Checked vet
# Checked disenfranchise
# Checked l
# Checked vouc

# %% [markdown]
# # Binary Search

# %%
def get_bin_search_results(text: str):
    os.chdir("bin")
    program_path = './binary_search'
    arguments = [text]
    subprocess.run([program_path] + arguments)
    with open("../output_files/output_bin_search.txt", 'r') as f:
        result = [x.replace('\n', '') for x in f.readlines()]
    os.chdir("..")
    return result

def check_bin_search(text):
    l1 = get_bin_search_results(text)
    l2 = [x for x in words if x.startswith(text)]
    return l1 == l2

# %%
for prefix in prefixes:
    print(f"Checking {prefix}")
    if not check_bin_search(prefix):
        raise Exception(f"Failed for {prefix}")
# Out:
# Checking abus
# Checking purgatory
# Checking lif
# Checking Marpl
# Checking emotio
# Checking ballpoi
# Checking dru
# Checking vapidness'
# Checking Creole
# Checking franchise
# Checking illustrator'
# Checking aneur
# Checking increa
# Checking serg
# Checking haws
# Checking del
# Checking reparat
# Checking t
# Checking sw
# Checking Gabl
# Checking irra
# Checking coronaviru
# Checking tames
# Checking Potsdam'
# Checking geo
# Checking siblin
# Checking Dawe
# Checking Mar
# Checking disr
# Checking derang
# Checking birc
# Checking I
# Checking unfurle
# Checking entertai
# Checking Cyclo
# Checking pai
# Checking po
# Checking i
# Checking owe
# Checking snivelle
# Checking iter
# Checking Ard
# Checking slowpo
# Checking teletypewri
# Checking blackmail
# Checking Worces
# Checking pre
# Checking flu
# Checking outag
# Checking bonuse
# Checking cen
# Checking inve
# Checking M
# Checking C
# Checking divorci
# Checking adie
# Checking clo
# Checking equato
# Checking en
# Checking proneness'
# Checking de
# Checking needless
# Checking excheq
# Checking vul
# Checking Rutgers
# Checking br
# Checking shrew
# Checking ye
# Checking newe
# Checking retrofitte
# Checking com
# Checking stumbl
# Checking wallo
# Checking blo
# Checking adden
# Checking weatherproof
# Checking analogu
# Checking vi
# Checking w
# Checking Bar
# Checking audit
# Checking impoun
# Checking su
# Checking c
# Checking q
# Checking ti
# Checking gur
# Checking flo
# Checking enact
# Checking courteousn
# Checking Re
# Checking ge
# Checking un
# Checking veer
# Checking oldi
# Checking Pen
# Checking re
# Checking t
# Checking o
# Checking waterm
# Checking levelin
# Checking C
# Checking dr
# Checking Qu
# Checking cobblest
# Checking Re
# Checking Kathie'
# Checking sco
# Checking scol
# Checking ti
# Checking Sa
# Checking Judas
# Checking ski
# Checking broomsti
# Checking d
# Checking tim
# Checking dis
# Checking poll
# Checking a
# Checking declamation'
# Checking N
# Checking fighting
# Checking Bissau
# Checking in
# Checking tra
# Checking costing
# Checking hobbi
# Checking go
# Checking naked
# Checking clic
# Checking pla
# Checking n
# Checking Mena
# Checking Menelau
# Checking shl
# Checking qua
# Checking locksmi
# Checking bitterne
# Checking tw
# Checking osteo
# Checking overwriti
# Checking pa
# Checking malig
# Checking cata
# Checking A
# Checking manifest
# Checking con
# Checking craw
# Checking timberli
# Checking tea
# Checking prov
# Checking fev
# Checking Mar
# Checking Sheraton
# Checking export
# Checking L
# Checking prize
# Checking brot
# Checking pump
# Checking canopyi
# Checking phosphores
# Checking t
# Checking ful
# Checking evolutio
# Checking curvie
# Checking Ma
# Checking r
# Checking verisimilitu
# Checking expiratio
# Checking baller
# Checking q
# Checking blesse
# Checking expectoratio
# Checking Ba
# Checking lo
# Checking Agricola
# Checking vo
# Checking bilge'
# Checking No
# Checking ung
# Checking lo
# Checking staini
# Checking analog
# Checking Schin
# Checking pin
# Checking Jinnah
# Checking rob
# Checking pal
# Checking Chav
# Checking quiet
# Checking rela
# Checking d
# Checking paraplegia
# Checking pr
# Checking charco
# Checking misquot
# Checking discom
# Checking ski
# Checking handym
# Checking deni
# Checking G
# Checking enamo
# Checking hardhearte
# Checking trundl
# Checking Sophocle
# Checking detainment
# Checking cardsha
# Checking beh
# Checking affl
# Checking v
# Checking Sal
# Checking underestimat
# Checking jungl
# Checking lau
# Checking sca
# Checking co
# Checking Pi
# Checking celebratio
# Checking crucifor
# Checking gondo
# Checking Laiu
# Checking c
# Checking dou
# Checking fi
# Checking C
# Checking BIT
# Checking na
# Checking mum
# Checking p
# Checking que
# Checking f
# Checking cloakroo
# Checking A
# Checking toothso
# Checking complaisa
# Checking splo
# Checking flooring
# Checking plu
# Checking wraparoun
# Checking endiv
# Checking Xin
# Checking reappointme
# Checking pella
# Checking Mandelbrot
# Checking Mencius
# Checking a
# Checking cens
# Checking reb
# Checking essen
# Checking demis
# Checking wei
# Checking aliase
# Checking cadr
# Checking Excellenc
# Checking manikin'
# Checking pila
# Checking he
# Checking ro
# Checking Bere
# Checking l
# Checking morti
# Checking misha
# Checking bath
# Checking goble
# Checking G
# Checking hon
# Checking cro
# Checking Confederac
# Checking hija
# Checking c
# Checking a
# Checking levitatio
# Checking bela
# Checking swellhead
# Checking prove
# Checking Rastafari
# Checking teet
# Checking Adirondacks
# Checking murkies
# Checking quaki
# Checking u
# Checking pige
# Checking lo
# Checking Ogd
# Checking Da
# Checking disme
# Checking Tann
# Checking Billy'
# Checking rec
# Checking predicativ
# Checking bubb
# Checking Keit
# Checking ora
# Checking su
# Checking cu
# Checking Kath
# Checking nestlin
# Checking s
# Checking st
# Checking Pleiades
# Checking Enkidu
# Checking Cape
# Checking Berbe
# Checking Glastonbury
# Checking Q
# Checking Cryp
# Checking f
# Checking s
# Checking b
# Checking aus
# Checking of
# Checking E
# Checking oppo
# Checking intert
# Checking j
# Checking Balk
# Checking su
# Checking fresh
# Checking incubus'
# Checking b
# Checking i
# Checking f
# Checking undet
# Checking je
# Checking s
# Checking Abb
# Checking rei
# Checking pinhole
# Checking s
# Checking intrusi
# Checking councilwom
# Checking sheepishness
# Checking God
# Checking ski
# Checking R
# Checking j
# Checking B
# Checking Bor
# Checking tit
# Checking Quixo
# Checking co
# Checking poac
# Checking comp
# Checking mad
# Checking undi
# Checking exp
# Checking Coppola'
# Checking deathle
# Checking cras
# Checking medulla
# Checking in
# Checking ou
# Checking d
# Checking w
# Checking m
# Checking ove
# Checking faste
# Checking felt
# Checking Wa
# Checking ex
# Checking Hoope
# Checking priva
# Checking blin
# Checking monas
# Checking s
# Checking sc
# Checking fall
# Checking inte
# Checking hu
# Checking bra
# Checking to
# Checking Tal
# Checking kamikaz
# Checking or
# Checking Tampa
# Checking Lusaka
# Checking Yak
# Checking Ant
# Checking rev
# Checking clearing
# Checking blus
# Checking ampu
# Checking Muh
# Checking prett
# Checking writi
# Checking beam
# Checking ov
# Checking ta
# Checking b
# Checking inevita
# Checking opio
# Checking Erni
# Checking cach
# Checking swilli
# Checking Br
# Checking old
# Checking sea
# Checking adequ
# Checking sabre'
# Checking exce
# Checking masc
# Checking assertiv
# Checking sh
# Checking bu
# Checking es
# Checking agribusine
# Checking glock
# Checking nob
# Checking absenc
# Checking Ve
# Checking h
# Checking E
# Checking ven
# Checking oil
# Checking re
# Checking rasc
# Checking vitupe
# Checking Kirby
# Checking wo
# Checking cadge
# Checking iro
# Checking PT
# Checking flatto
# Checking taber
# Checking unde
# Checking po
# Checking grandmo
# Checking cr
# Checking re
# Checking p
# Checking stub
# Checking underg
# Checking pilothouse
# Checking Wilfred
# Checking popg
# Checking Alexe
# Checking ru
# Checking Mine
# Checking recruit
# Checking so
# Checking regime
# Checking tor
# Checking Taipei'
# Checking Ca
# Checking overheat
# Checking f
# Checking yak
# Checking dri
# Checking pav
# Checking kno
# Checking R
# Checking mood
# Checking StairMaster'
# Checking ce
# Checking De
# Checking mou
# Checking kick
# Checking bac
# Checking adven
# Checking look
# Checking worthles
# Checking mantelpie
# Checking Apollinair
# Checking je
# Checking code
# Checking fin
# Checking pooch
# Checking pe
# Checking i
# Checking Da
# Checking immu
# Checking senna
# Checking minic
# Checking repug
# Checking Rea
# Checking sweep
# Checking marks
# Checking s
# Checking t
# Checking tyra
# Checking stigma
# Checking g
# Checking retrie
# Checking upsta
# Checking Steub
# Checking waln
# Checking C
# Checking ca
# Checking clic
# Checking fros
# Checking ar
# Checking Bundesba
# Checking ESP'
# Checking wret
# Checking priss
# Checking esthet
# Checking hum
# Checking sh
# Checking crin
# Checking dy
# Checking exhausti
# Checking i
# Checking aphori
# Checking S
# Checking mayo
# Checking bisho
# Checking m
# Checking l
# Checking s
# Checking pig
# Checking idi
# Checking af
# Checking Blo
# Checking unscra
# Checking wingl
# Checking wave
# Checking citi
# Checking adjectiv
# Checking redoubt
# Checking b
# Checking debt
# Checking manicuri
# Checking deli
# Checking ful
# Checking awr
# Checking c
# Checking longshor
# Checking s
# Checking de
# Checking enf
# Checking tabl
# Checking Cla
# Checking ref
# Checking tomb
# Checking impu
# Checking blackball
# Checking synd
# Checking mo
# Checking be
# Checking p
# Checking kest
# Checking grumpi
# Checking Fic
# Checking Uni
# Checking sa
# Checking sup
# Checking Mel
# Checking ba
# Checking salv
# Checking fut
# Checking bribin
# Checking neoclassicis
# Checking chatti
# Checking Vulca
# Checking brood'
# Checking demeani
# Checking d
# Checking regulato
# Checking bide
# Checking cli
# Checking Keller'
# Checking fraterni
# Checking r
# Checking re
# Checking opi
# Checking pola
# Checking alimony
# Checking whorle
# Checking D
# Checking anecd
# Checking b
# Checking he
# Checking linesman'
# Checking gal
# Checking w
# Checking bas
# Checking Os
# Checking cospons
# Checking by
# Checking parit
# Checking strangulat
# Checking apos
# Checking antic
# Checking Dorothe
# Checking flat
# Checking nu
# Checking I
# Checking ben
# Checking unr
# Checking garbagema
# Checking co
# Checking i
# Checking flowerp
# Checking ha
# Checking g
# Checking over
# Checking p
# Checking abstrac
# Checking re
# Checking riffle
# Checking skid
# Checking ad
# Checking sectar
# Checking turquoi
# Checking wristb
# Checking fo
# Checking hyperte
# Checking counten
# Checking pard
# Checking att
# Checking Ver
# Checking sa
# Checking c
# Checking tr
# Checking e
# Checking fas
# Checking S
# Checking accuser
# Checking hybr
# Checking s
# Checking sun
# Checking understudie
# Checking deve
# Checking chrysalise
# Checking Hammer
# Checking fir
# Checking vis
# Checking scatterbrain
# Checking putrefactio
# Checking rudde
# Checking Sui
# Checking com
# Checking spine
# Checking n
# Checking tra
# Checking eagerne
# Checking Da
# Checking la
# Checking misconstructi
# Checking B
# Checking shro
# Checking bandyin
# Checking an
# Checking kn
# Checking jo
# Checking headq
# Checking F
# Checking fortress
# Checking immaturit
# Checking p
# Checking inertness'
# Checking pantsuit
# Checking Canopus'
# Checking roto
# Checking isthmu
# Checking Bur
# Checking hol
# Checking C
# Checking whi
# Checking metron
# Checking tr
# Checking emotio
# Checking bree
# Checking Genet
# Checking hus
# Checking fie
# Checking m
# Checking resis
# Checking bowl
# Checking BAS
# Checking Ausc
# Checking beq
# Checking c
# Checking n
# Checking imperson
# Checking naugh
# Checking V
# Checking C
# Checking stuffin
# Checking observ
# Checking Pie
# Checking perv
# Checking S
# Checking confis
# Checking ya
# Checking rem
# Checking p
# Checking be
# Checking fo
# Checking ta
# Checking fault'
# Checking Oakle
# Checking p
# Checking co
# Checking w
# Checking AN
# Checking wound
# Checking Elizabethtow
# Checking faithless
# Checking harri
# Checking St
# Checking hank
# Checking Vinc
# Checking compo
# Checking lexicogr
# Checking displ
# Checking h
# Checking ge
# Checking ne
# Checking u
# Checking abat
# Checking lapto
# Checking tr
# Checking observance
# Checking beste
# Checking ounce
# Checking cas
# Checking metap
# Checking patc
# Checking br
# Checking in
# Checking cannies
# Checking atmos
# Checking overdre
# Checking pomp
# Checking stopligh
# Checking recapi
# Checking E
# Checking typ
# Checking incorpo
# Checking Dar
# Checking Matlab'
# Checking bowling'
# Checking reb
# Checking syph
# Checking Ro
# Checking competen
# Checking su
# Checking detestation'
# Checking bo
# Checking fill
# Checking over
# Checking inc
# Checking NS
# Checking freightin
# Checking ampl
# Checking He
# Checking distraugh
# Checking sevent
# Checking mi
# Checking son
# Checking do
# Checking exi
# Checking Vladi
# Checking subord
# Checking procurer
# Checking howler'
# Checking analyst'
# Checking cutthroat'
# Checking solic
# Checking adj
# Checking po
# Checking cili
# Checking be
# Checking magnifyi
# Checking cameo'
# Checking id
# Checking ent
# Checking el
# Checking unconscionabl
# Checking dis
# Checking p
# Checking option'
# Checking ins
# Checking aut
# Checking tremble
# Checking upr
# Checking i
# Checking singl
# Checking ele
# Checking Do
# Checking opt
# Checking dairymai
# Checking Beach'
# Checking c
# Checking ni
# Checking reta
# Checking ref
# Checking sta
# Checking whip
# Checking advent
# Checking P
# Checking beat
# Checking persev
# Checking C
# Checking c
# Checking q
# Checking Jez
# Checking q
# Checking Os
# Checking w
# Checking recla
# Checking cage'
# Checking tr
# Checking m
# Checking ep
# Checking dis
# Checking s
# Checking barra
# Checking b
# Checking noncooperat
# Checking dispense
# Checking gra
# Checking elo
# Checking do
# Checking Maracai
# Checking a
# Checking palmies
# Checking newton'
# Checking pred
# Checking ea
# Checking salespeopl
# Checking sp
# Checking carc
# Checking Este
# Checking thi
# Checking sols
# Checking t
# Checking Pyt
# Checking fiel
# Checking interme
# Checking budge
# Checking antiphona
# Checking Luc
# Checking hexe
# Checking El
# Checking teas
# Checking co
# Checking cumula
# Checking boate
# Checking Yb'
# Checking w
# Checking de
# Checking i
# Checking sa
# Checking Wond
# Checking disloc
# Checking motivat
# Checking totterin
# Checking constituti
# Checking Tu
# Checking ap
# Checking marki
# Checking Du
# Checking l
# Checking E
# Checking Casca
# Checking for
# Checking Fried
# Checking visualize
# Checking optician
# Checking om
# Checking capill
# Checking over
# Checking unc
# Checking madras
# Checking insubordin
# Checking declivity'
# Checking d'Estain
# Checking invei
# Checking neurotransmi
# Checking wave
# Checking am
# Checking ar
# Checking wav
# Checking pu
# Checking fl
# Checking gly
# Checking Rena
# Checking h
# Checking abs
# Checking cozine
# Checking Babyl
# Checking tortil
# Checking gero
# Checking cannabi
# Checking Ha
# Checking be
# Checking embodiment'
# Checking nuzzle
# Checking squirrell
# Checking Vishnu'
# Checking t
# Checking dresse
# Checking l
# Checking Darl
# Checking truncat
# Checking firt
# Checking raucou
# Checking t
# Checking heteros
# Checking mo
# Checking fende
# Checking marine
# Checking Na
# Checking cra
# Checking bl
# Checking wedge'
# Checking hostler
# Checking reneg
# Checking motherhoo
# Checking m
# Checking unionizati
# Checking t
# Checking villa'
# Checking fla
# Checking sies
# Checking tyrann
# Checking W
# Checking dash
# Checking assa
# Checking idea
# Checking Mid
# Checking co
# Checking serenit
# Checking K
# Checking nonhazardo
# Checking ve
# Checking maro
# Checking ch
# Checking Kotlin
# Checking sedates
# Checking Keoku
# Checking q
# Checking mo
# Checking cert
# Checking multiple
# Checking dro
# Checking spa
# Checking enve
# Checking valen
# Checking repossess
# Checking coerc
# Checking dis
# Checking fa
# Checking sho
# Checking f
# Checking fl
# Checking plas
# Checking c
# Checking P
# Checking concili
# Checking pe
# Checking h
# Checking te
# Checking ram
# Checking praline
# Checking banya
# Checking war
# Checking P
# Checking bowler
# Checking Chin
# Checking absur
# Checking precipi
# Checking beauti
# Checking O
# Checking flight
# Checking fle
# Checking pugna
# Checking g
# Checking grid
# Checking ES
# Checking ev
# Checking visual
# Checking syn
# Checking cog
# Checking del
# Checking wh
# Checking Annap
# Checking s
# Checking re
# Checking g
# Checking frow
# Checking backb
# Checking Chatte
# Checking Folsom
# Checking V
# Checking ke
# Checking sui
# Checking portcullis
# Checking apostat
# Checking Dion
# Checking h
# Checking multi
# Checking welfa
# Checking Lo
# Checking vet
# Checking disenfranchise
# Checking l
# Checking vouc

# %% [markdown]
# # Levestein

# %%
import textdistance

# %%
retrieve_levestein_dist = textdistance.levenshtein

# %%
def levestein(text, max_dist):
    output = []
    for word in words:
        dist = retrieve_levestein_dist(word, text)
        if dist <= max_dist:
            output.append(word)
    return output

def get_cpp_levestein_results(text: str, dist: int):
    os.chdir("bin")
    program_path = './levestein'
    arguments = [text, str(dist)]
    subprocess.run([program_path] + arguments, text=True, capture_output=True)
    with open("../output_files/output_levestein.txt", 'r') as f:
        result = [x.replace('\n', '') for x in f.readlines()]
    result.sort()
    os.chdir("..")
    return result

def check_levestein(text, dist):
    return get_cpp_levestein_results(text, dist) == levestein(text, dist)

# %%
get_cpp_levestein_results("AAA", 1)
# Out:
# ['AA', 'AAA', 'AMA', 'FAA']

# %%
levestein("AAA", 1)
# Out:
# ['AA', 'AAA', 'AMA', 'FAA']

# %%
check_levestein("AAA", 1)
# Out:
# True

# %%
# [delete , add, replace, maintain]
maintain = 0.9
others = (1 - maintain)/3
porcentages = [others, others, others, maintain]
assert sum(porcentages) == 1
accumulated = 0
intervals = []
for porcentage in porcentages:
    accumulated += porcentage
    intervals.append(accumulated)

# %%
def get_action(number: float):
    output = 0
    while number > intervals[output]:
        output += 1
    return output

# %%
num_samples = 10

# %%
words_levestein = []
originals = []
for word in random.sample(words, num_samples):
    curr_word = ""
    curr_char_idx = 0
    while curr_char_idx != len(word):
        action = get_action(random.uniform(0, 1))
        # Delete char
        if action == 0:
            curr_char_idx += 1
        # Add random char
        elif action == 1:
            random_char = random.choice(string.ascii_letters)
            curr_word += random_char
        # Replace char
        elif action == 2:
            random_char = random.choice(string.ascii_letters)
            curr_word += random_char
            curr_char_idx += 1
        # Maintain char
        elif action == 3:
            curr_word += word[curr_char_idx]
            curr_char_idx += 1
    words_levestein.append(curr_word)
    originals.append(word)

# %%
index = 1
words_levestein[index], originals[index]
# Out:
# ('unquesvtiBning', 'unquestioning')

# %%
errors = []
for word in words_levestein[:100]:
    print(f"Checking {word}")
    for dist in range(4):
        if not check_levestein(word, dist):
            print(f"Failed for {word} and {dist}")
            errors.append((word, dist))
# Out:
# Checking godforsaken
# Checking unquesvtiBning
# Checking booils
# Checking systematic
# Checking stationers
# Checking slinks
# Checking vashiki's
# Checking Grayslake's
# Checking questioner'ts
# Checking sketAGing
