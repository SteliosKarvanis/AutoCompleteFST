# %% [markdown]
# # Test Notebook

# %% [markdown]
# ## Code

# %%
import random
import string
import subprocess
import os

# %%
os.chdir("..")

# %% [markdown]
# Read the dictionary

# %%
words = []
with open("data/american_english_sorted.txt", 'r') as f:
    for word in f.readlines():
        words.append(word.replace('\n', ''))

# %% [markdown]
# Generate random prefixes

# %%
num_samples = 10000

# %%
prefixes = []
for word in random.sample(words, num_samples):
    while(len(word) < 2):
        word = random.choice(words)
    rand_int = random.randint(1, len(word)-1)
    prefix = word[:rand_int]
    prefixes.append(prefix)

# %% [markdown]
# Save prefix examples to file

# %%
os.makedirs("tmp", exist_ok=True)
with open("tmp/examples.txt", "w") as f:
    for x in prefixes:
        f.write(x)
        f.write("\n")

# %%
prefixes[:5]
# Out:
# ['no', 'h', 'Mohamme', 'lac', 'dioxi']

# %% [markdown]
# To generate random prefixes with a fix length:

# %%
def get_random(prefix_len: int):
    while True:
        word = random.choice(words)
        if len(word) >= prefix_len:
            break
    return word[:prefix_len]

def get_result(prefix: str):
    return [x for x in words if x.startswith(prefix)]

# %%
prefix = get_random(prefix_len=4)
results = get_result(prefix)
print(prefix) 
print(results)
# Out:
# Jidd
# ['Jidda', "Jidda's"]

# %%
def gen_results():
    os.remove("output_files/output_autocomplete.txt")
    os.chdir("bin")
    program_path = './autocomplete'
    arguments = ["../tmp/examples.txt"]
    subprocess.run([program_path] + arguments, text=True, capture_output=True)
    os.chdir("..")

def get_cpp_results():
    results = []
    with open("output_files/output_autocomplete.txt", 'r') as f:
        for line in f.readlines():
            line = line.replace("\n", "").strip()
            if line == ']':
                yield results
                results = []
            if line and not line == '[' and not line == ']':
                results.append(line)
            

def gen_expected_results():
    with open("tmp/examples.txt", 'r') as f:
        for line in f.readlines():
            line = line.replace('\n', '').strip()
            yield [x for x in words if x.startswith(line)]

def check_autocomplete():
    keys = []
    with open("tmp/examples.txt", 'r') as f:
        for line in f.readlines():
            line = line.replace('\n', '').strip()
            keys.append(line)
        
    for key, l1, l2 in zip(keys, get_cpp_results(), gen_expected_results()):
        if l1 != l2:
            print(f"Failed for {key}")
            print([x for x in l1 if x not in l2])
            print([x for x in l2 if x not in l1])
            return False
        else:
            print(f"Checked {key}")

# %%
gen_results()

# %%
check_autocomplete()
# Out:
# Checked di
# Checked Powe
# Checked ony
# Checked Sveng
# Checked tonsu
# Checked leav
# Checked c
# Checked dr
# Checked smu
# Checked bobwhite
# Checked hermita
# Checked ground
# Checked inu
# Checked K
# Checked zo
# Checked onslaug
# Checked comprehe
# Checked am
# Checked cru
# Checked clearinghouse'
# Checked Chang
# Checked Myst'
# Checked todd
# Checked cro
# Checked F
# Checked e
# Checked intrica
# Checked phonolo
# Checked c
# Checked uncommon
# Checked umb
# Checked Hellm
# Checked mirthf
# Checked mispronunci
# Checked Robes
# Checked emolum
# Checked Massachuse
# Checked unan
# Checked pl
# Checked wayfarer'
# Checked ser
# Checked lo
# Checked sette
# Checked ventri
# Checked nexu
# Checked in
# Checked Miss
# Checked deafnes
# Checked Evangel
# Checked com
# Checked bere
# Checked c
# Checked wi
# Checked sympathiz
# Checked blows
# Checked Sophoclean
# Checked wadi
# Checked hypoglyce
# Checked randomize
# Checked swishe
# Checked ju
# Checked Cl
# Checked commanda
# Checked airpl
# Checked cou
# Checked doctrinair
# Checked disambigua
# Checked Loe
# Checked motorca
# Checked si
# Checked wrongdoe
# Checked wom
# Checked potte
# Checked tern'
# Checked empan
# Checked foo
# Checked hai
# Checked Hi
# Checked b
# Checked hodgepod
# Checked AOL'
# Checked Elis
# Checked d
# Checked sh
# Checked masculi
# Checked twiligh
# Checked co
# Checked cableg
# Checked Finn
# Checked skater
# Checked w
# Checked co
# Checked A
# Checked irrevoca
# Checked st
# Checked s
# Checked x
# Checked yodeler
# Checked inferio
# Checked bo
# Checked jeweli
# Checked w
# Checked ch
# Checked sho
# Checked h
# Checked a
# Checked bal
# Checked depol
# Checked le
# Checked ways
# Checked c
# Checked inf
# Checked v
# Checked inaugur
# Checked fing
# Checked burn
# Checked suppo
# Checked heck'
# Checked measur
# Checked Elsinor
# Checked Tong
# Checked madrig
# Checked jeopardy
# Checked birthma
# Checked tar
# Checked inflat
# Checked cate
# Checked resurfa
# Checked squeak
# Checked flooz
# Checked Jen
# Checked predicti
# Checked sol
# Checked endor
# Checked le
# Checked Alba
# Checked cu
# Checked snow
# Checked miss
# Checked co
# Checked legr
# Checked Ha
# Checked host
# Checked g
# Checked we
# Checked check
# Checked Gals
# Checked w
# Checked small
# Checked digestio
# Checked tra
# Checked re
# Checked Arl
# Checked ejecte
# Checked cu
# Checked Pho
# Checked fatuousnes
# Checked scat
# Checked lo
# Checked stock
# Checked b
# Checked bluffes
# Checked un
# Checked Jo
# Checked repen
# Checked astronom
# Checked viol
# Checked jackknife
# Checked g
# Checked fi
# Checked bunku
# Checked scr
# Checked Debb
# Checked r
# Checked bl
# Checked slave
# Checked out
# Checked f
# Checked vo
# Checked c
# Checked locku
# Checked schola
# Checked Gra
# Checked exten
# Checked ev
# Checked esthete
# Checked ro
# Checked fun
# Checked lectu
# Checked Klingo
# Checked Tancre
# Checked fr
# Checked chapar
# Checked coagu
# Checked Cra
# Checked tailcoa
# Checked dia
# Checked Accentur
# Checked Tegucigalpa'
# Checked hip
# Checked Russel
# Checked ha
# Checked syn
# Checked grandfat
# Checked stenc
# Checked S
# Checked St
# Checked trudge
# Checked film
# Checked naught
# Checked sea
# Checked Lati
# Checked gon
# Checked Nazii
# Checked Cochaba
# Checked subjugatio
# Checked justificati
# Checked HQ
# Checked superh
# Checked Yea
# Checked s
# Checked te
# Checked diki
# Checked S
# Checked sagg
# Checked espou
# Checked over
# Checked side
# Checked sh
# Checked Darlen
# Checked Ha
# Checked silence
# Checked Monr
# Checked g
# Checked Marx'
# Checked pimie
# Checked sc
# Checked sh
# Checked M
# Checked Hanfor
# Checked collocati
# Checked Maui'
# Checked aneurysm
# Checked scandalo
# Checked loo
# Checked ba
# Checked Nann
# Checked si
# Checked pa
# Checked Republ
# Checked belli
# Checked cas
# Checked comm
# Checked Harl
# Checked co
# Checked d
# Checked F
# Checked flos
# Checked c
# Checked Ram
# Checked ret
# Checked outlive
# Checked covenant
# Checked exa
# Checked Mar
# Checked Gordim
# Checked lake
# Checked FH
# Checked castigati
# Checked assass
# Checked enl
# Checked Altipla
# Checked Garrick'
# Checked Le
# Checked posterit
# Checked ba
# Checked equilib
# Checked tough
# Checked genocide
# Checked unaff
# Checked consci
# Checked participa
# Checked thr
# Checked road
# Checked po
# Checked Montgomer
# Checked interroga
# Checked br
# Checked smot
# Checked liqu
# Checked glyc
# Checked s
# Checked gues
# Checked Br
# Checked contusi
# Checked Jo
# Checked bluebel
# Checked adr
# Checked technical
# Checked speedboa
# Checked wher
# Checked Kr
# Checked c
# Checked signif
# Checked C
# Checked gri
# Checked handle
# Checked pulley
# Checked leuk
# Checked micro
# Checked overbal
# Checked sli
# Checked Ijs
# Checked te
# Checked riv
# Checked f
# Checked l
# Checked spaciousne
# Checked vibrato
# Checked cy
# Checked brusque
# Checked y'a
# Checked Kathl
# Checked j
# Checked lazybones
# Checked slalom
# Checked An
# Checked mouser
# Checked decontamina
# Checked bo
# Checked butter
# Checked un
# Checked s
# Checked T
# Checked Vi
# Checked inci
# Checked un
# Checked ca
# Checked timepiece
# Checked s
# Checked fli
# Checked s
# Checked replicato
# Checked R
# Checked au
# Checked rea
# Checked s
# Checked jur
# Checked bus
# Checked c
# Checked gher
# Checked cacophonie
# Checked u
# Checked dizzie
# Checked br
# Checked d
# Checked expositi
# Checked pr
# Checked d
# Checked Decca'
# Checked Parn
# Checked h
# Checked porta
# Checked m
# Checked ab
# Checked engagem
# Checked la
# Checked cas
# Checked Mus
# Checked infer
# Checked show
# Checked Iraq
# Checked statuett
# Checked millepede
# Checked brandish
# Checked spu
# Checked B
# Checked f
# Checked dealer
# Checked emba
# Checked di
# Checked stingra
# Checked nonparei
# Checked zwi
# Checked Ol
# Checked c
# Checked Semiram
# Checked c
# Checked le
# Checked Algi
# Checked secessionis
# Checked Carlen
# Checked o
# Checked Ta
# Checked Gul
# Checked L
# Checked interchangea
# Checked clamb
# Checked werewolv
# Checked fiscal
# Checked swindl
# Checked conf
# Checked blackberry
# Checked platfo
# Checked f
# Checked ca
# Checked Ma
# Checked pedicu
# Checked lispi
# Checked to
# Checked ha
# Checked seaso
# Checked vehic
# Checked qua
# Checked stag
# Checked reddene
# Checked lite
# Checked gl
# Checked regici
# Checked Cont
# Checked wi
# Checked p
# Checked h
# Checked nominat
# Checked dizzies
# Checked gu
# Checked evinc
# Checked gi
# Checked spare
# Checked lif
# Checked si
# Checked Duf
# Checked postc
# Checked sa
# Checked mammogra
# Checked c
# Checked sa
# Checked goo
# Checked canard'
# Checked sn
# Checked sin
# Checked curlicue'
# Checked adv
# Checked Bene
# Checked ta
# Checked flo
# Checked corpse'
# Checked gal
# Checked Ada
# Checked ayato
# Checked Marjo
# Checked academ
# Checked igua
# Checked c
# Checked ep
# Checked c
# Checked insig
# Checked batteni
# Checked selfles
# Checked restle
# Checked preposition
# Checked fricassee'
# Checked Me
# Checked cut
# Checked Alphonse'
# Checked Finni
# Checked v
# Checked cat
# Checked b
# Checked hu
# Checked combi
# Checked di
# Checked backre
# Checked Co
# Checked legi
# Checked shirtsle
# Checked Farsi'
# Checked pe
# Checked indis
# Checked sp
# Checked exha
# Checked J
# Checked motle
# Checked saddleb
# Checked moo
# Checked disengag
# Checked mang
# Checked restu
# Checked corti
# Checked c
# Checked yea
# Checked Delmar
# Checked carja
# Checked br
# Checked c
# Checked hig
# Checked movab
# Checked Tantalu
# Checked o
# Checked gam
# Checked contra
# Checked repriev
# Checked Chun
# Checked s
# Checked Toni
# Checked R
# Checked shortl
# Checked Jo
# Checked vas
# Checked V
# Checked beso
# Checked su
# Checked tireso
# Checked repriman
# Checked assist
# Checked cop
# Checked dex
# Checked fluff
# Checked congratulat
# Checked mutua
# Checked van
# Checked s
# Checked groo
# Checked retort
# Checked Zionis
# Checked circumspecti
# Checked par
# Checked ince
# Checked A
# Checked ba
# Checked conceptualiz
# Checked r
# Checked Dick
# Checked free
# Checked rec
# Checked wholesomen
# Checked bri
# Checked psych
# Checked coife
# Checked Co
# Checked sandcast
# Checked muc
# Checked interpret
# Checked pu
# Checked mi
# Checked sagac
# Checked e
# Checked ha
# Checked numbl
# Checked tra
# Checked Wikipe
# Checked misbeg
# Checked Th
# Checked unders
# Checked ru
# Checked purs
# Checked la
# Checked billfol
# Checked Sikh'
# Checked pitchman
# Checked sn
# Checked leg
# Checked stranglehold
# Checked outstat
# Checked smalli
# Checked milks
# Checked briber
# Checked imputat
# Checked ti
# Checked tyrannic
# Checked disea
# Checked vesic
# Checked reiss
# Checked anticipat
# Checked A
# Checked brainwash
# Checked Keish
# Checked arist
# Checked pacifi
# Checked g
# Checked int
# Checked d
# Checked hic
# Checked hypn
# Checked bias'
# Checked sta
# Checked effer
# Checked minera
# Checked snu
# Checked Gu
# Checked p
# Checked i
# Checked sw
# Checked insurge
# Checked farro
# Checked vaunt
# Checked whetst
# Checked Newt
# Checked creat
# Checked cooper
# Checked mans
# Checked Hercul
# Checked wir
# Checked ho
# Checked Lag
# Checked sand
# Checked dela
# Checked Brati
# Checked vapo
# Checked st
# Checked k
# Checked s
# Checked lowd
# Checked bi
# Checked vocal
# Checked fetin
# Checked L
# Checked trum
# Checked Attuck
# Checked unk
# Checked tendonitis
# Checked optimi
# Checked ma
# Checked fa
# Checked calve
# Checked hap
# Checked e
# Checked over'
# Checked came
# Checked updraft
# Checked to
# Checked yoghur
# Checked redden
# Checked refrigeran
# Checked via
# Checked s
# Checked sm
# Checked experimen
# Checked airfoi
# Checked Calv
# Checked t
# Checked pinio
# Checked Sassoon'
# Checked flo
# Checked mo
# Checked quadruplet'
# Checked f
# Checked Beth'
# Checked req
# Checked scal
# Checked tea
# Checked di
# Checked tro
# Checked cream'
# Checked extin
# Checked fertilize
# Checked motiv
# Checked n
# Checked Roosev
# Checked may
# Checked Nikki'
# Checked ch
# Checked po
# Checked o
# Checked g
# Checked printe
# Checked j
# Checked Rei
# Checked utt
# Checked shuffli
# Checked awak
# Checked go'
# Checked ax
# Checked Redgrave
# Checked flatte
# Checked chee
# Checked E
# Checked nuan
# Checked slo
# Checked beautif
# Checked Kansan'
# Checked car
# Checked na
# Checked Eucha
# Checked scoreles
# Checked disposition
# Checked pond
# Checked appendice
# Checked stabilizati
# Checked hou
# Checked disinte
# Checked chastel
# Checked overs
# Checked epoxie
# Checked c
# Checked presumi
# Checked grap
# Checked impriso
# Checked no
# Checked fasci
# Checked overra
# Checked kaleid
# Checked immov
# Checked pres
# Checked griddl
# Checked ca
# Checked seedie
# Checked hy
# Checked overch
# Checked cy
# Checked phlebi
# Checked vinta
# Checked narrowne
# Checked cou
# Checked Bridge
# Checked call
# Checked dodde
# Checked R
# Checked Zuko
# Checked Li
# Checked co
# Checked enligh
# Checked v
# Checked sieve
# Checked Shau
# Checked hoodoo
# Checked distressingl
# Checked airfiel
# Checked Glen
# Checked counterattac
# Checked I
# Checked spind
# Checked painst
# Checked dermati
# Checked sw
# Checked Ol
# Checked factionalis
# Checked d
# Checked Battl
# Checked m
# Checked L
# Checked muste
# Checked huntre
# Checked sie
# Checked deflect
# Checked o
# Checked fence
# Checked pacifist'
# Checked te
# Checked ringsid
# Checked for
# Checked galva
# Checked Jeff
# Checked Parsifal'
# Checked Hieronymu
# Checked romantical
# Checked Laverne'
# Checked significatio
# Checked washbo
# Checked s
# Checked n
# Checked at
# Checked m
# Checked s
# Checked compatib
# Checked sp
# Checked a
# Checked bilingu
# Checked im
# Checked studio
# Checked chole
# Checked Cam
# Checked s
# Checked rel
# Checked parry
# Checked pene
# Checked exce
# Checked s
# Checked subornation
# Checked s
# Checked gangl
# Checked binding
# Checked visualize
# Checked moa
# Checked le
# Checked cu
# Checked orc
# Checked hemsti
# Checked Manson
# Checked Kha
# Checked firefl
# Checked Pas
# Checked Senio
# Checked r
# Checked j
# Checked r
# Checked e
# Checked overrat
# Checked rati
# Checked p
# Checked transp
# Checked hairin
# Checked Blavats
# Checked co
# Checked fetishis
# Checked f
# Checked P
# Checked h
# Checked d
# Checked S
# Checked dir
# Checked cuis
# Checked free
# Checked reem
# Checked ros
# Checked Khoisa
# Checked bloc
# Checked sc
# Checked info
# Checked Cu
# Checked c
# Checked d
# Checked We
# Checked heis
# Checked acquai
# Checked d
# Checked healthies
# Checked incu
# Checked su
# Checked a
# Checked recru
# Checked comfort
# Checked Ghani
# Checked Norwich'
# Checked mazurka
# Checked overaw
# Checked prejudgmen
# Checked Ma
# Checked ca
# Checked madho
# Checked straightf
# Checked d
# Checked pub
# Checked ar
# Checked vertica
# Checked a
# Checked Cl
# Checked ela
# Checked carewo
# Checked head
# Checked reenfo
# Checked leade
# Checked forew
# Checked bat
# Checked likel
# Checked federati
# Checked criti
# Checked motorbik
# Checked puri
# Checked disaffec
# Checked ref
# Checked h
# Checked f
# Checked Irishw
# Checked bl
# Checked c
# Checked Ru
# Checked Lisb
# Checked worthlessness'
# Checked glycoge
# Checked pollin
# Checked slay
# Checked novitia
# Checked p
# Checked C
# Checked spa
# Checked mys
# Checked jou
# Checked s
# Checked devi
# Checked Ru
# Checked contrave
# Checked Ha
# Checked pr
# Checked caddy
# Checked sauciness'
# Checked cartridge'
# Checked glarin
# Checked Et
# Checked chirop
# Checked Je
# Checked ensn
# Checked st
# Checked ear
# Checked Tokuga
# Checked guil
# Checked Le
# Checked disgu
# Checked vi
# Checked r
# Checked g
# Checked orang
# Checked du
# Checked a
# Checked rec
# Checked stag
# Checked enclo
# Checked rom
# Checked stew
# Checked T
# Checked culmination'
# Checked ukul
# Checked harness
# Checked nota
# Checked su
# Checked counterrevol
# Checked s
# Checked str
# Checked u
# Checked bur
# Checked hardheart
# Checked Stei
# Checked cont
# Checked frescoe
# Checked med
# Checked k
# Checked unmistak
# Checked ch
# Checked stym
# Checked C
# Checked ba
# Checked catac
# Checked adum
# Checked Hummer'
# Checked Co
# Checked cannonade
# Checked rejoi
# Checked Lu
# Checked waddl
# Checked parity
# Checked Hispa
# Checked windsur
# Checked vocal
# Checked dynamite
# Checked k
# Checked oxyace
# Checked e
# Checked ring
# Checked deb
# Checked Mormon
# Checked fou
# Checked sch
# Checked gaffi
# Checked su
# Checked sub
# Checked dietitia
# Checked rec
# Checked conjoine
# Checked weddi
# Checked m
# Checked grubstak
# Checked keyno
# Checked in
# Checked dismis
# Checked l
# Checked Grundy'
# Checked burs
# Checked flexibil
# Checked parente
# Checked cordial
# Checked mar
# Checked t
# Checked autograp
# Checked das
# Checked bulg
# Checked thatchin
# Checked wholesa
# Checked fairness'
# Checked i
# Checked rais
# Checked chlo
# Checked bibliogra
# Checked doomin
# Checked n
# Checked Urals
# Checked T
# Checked Wi
# Checked mi
# Checked dessert
# Checked cir
# Checked lit
# Checked huss
# Checked nov
# Checked unle
# Checked Blonde
# Checked pro
# Checked condesce
# Checked dankl
# Checked Et
# Checked breast

# %% [markdown]
# # Binary Search

# %%
def get_bin_search_results(text: str):
    os.chdir("bin")
    program_path = './binary_search'
    arguments = [text]
    subprocess.run([program_path] + arguments)
    with open("../output_files/output_bin_search.txt", 'r') as f:
        result = [x.replace('\n', '') for x in f.readlines()]
    os.chdir("..")
    return result

def check_bin_search(text):
    l1 = get_bin_search_results(text)
    l2 = [x for x in words if x.startswith(text)]
    return l1 == l2

# %%
for prefix in prefixes:
    print(f"Checking {prefix}")
    if not check_bin_search(prefix):
        raise Exception(f"Failed for {prefix}")
# Out:
# Checking di
# Checking Powe
# Checking ony
# Checking Sveng
# Checking tonsu
# Checking leav
# Checking c
# Checking dr
# Checking smu
# Checking bobwhite
# Checking hermita
# Checking ground
# Checking inu
# Checking K
# Checking zo
# Checking onslaug
# Checking comprehe
# Checking am
# Checking cru
# Checking clearinghouse'
# Checking Chang
# Checking Myst'
# Checking todd
# Checking cro
# Checking F
# Checking e
# Checking intrica
# Checking phonolo
# Checking c
# Checking uncommon
# Checking umb
# Checking Hellm
# Checking mirthf
# Checking mispronunci
# Checking Robes
# Checking emolum
# Checking Massachuse
# Checking unan
# Checking pl
# Checking wayfarer'
# Checking ser
# Checking lo
# Checking sette
# Checking ventri
# Checking nexu
# Checking in
# Checking Miss
# Checking deafnes
# Checking Evangel
# Checking com
# Checking bere
# Checking c
# Checking wi
# Checking sympathiz
# Checking blows
# Checking Sophoclean
# Checking wadi
# Checking hypoglyce
# Checking randomize
# Checking swishe
# Checking ju
# Checking Cl
# Checking commanda
# Checking airpl
# Checking cou
# Checking doctrinair
# Checking disambigua
# Checking Loe
# Checking motorca
# Checking si
# Checking wrongdoe
# Checking wom
# Checking potte
# Checking tern'
# Checking empan
# Checking foo
# Checking hai
# Checking Hi
# Checking b
# Checking hodgepod
# Checking AOL'
# Checking Elis
# Checking d
# Checking sh
# Checking masculi
# Checking twiligh
# Checking co
# Checking cableg
# Checking Finn
# Checking skater
# Checking w
# Checking co
# Checking A
# Checking irrevoca
# Checking st
# Checking s
# Checking x
# Checking yodeler
# Checking inferio
# Checking bo
# Checking jeweli
# Checking w
# Checking ch
# Checking sho
# Checking h
# Checking a
# Checking bal
# Checking depol
# Checking le
# Checking ways
# Checking c
# Checking inf
# Checking v
# Checking inaugur
# Checking fing
# Checking burn
# Checking suppo
# Checking heck'
# Checking measur
# Checking Elsinor
# Checking Tong
# Checking madrig
# Checking jeopardy
# Checking birthma
# Checking tar
# Checking inflat
# Checking cate
# Checking resurfa
# Checking squeak
# Checking flooz
# Checking Jen
# Checking predicti
# Checking sol
# Checking endor
# Checking le
# Checking Alba
# Checking cu
# Checking snow
# Checking miss
# Checking co
# Checking legr
# Checking Ha
# Checking host
# Checking g
# Checking we
# Checking check
# Checking Gals
# Checking w
# Checking small
# Checking digestio
# Checking tra
# Checking re
# Checking Arl
# Checking ejecte
# Checking cu
# Checking Pho
# Checking fatuousnes
# Checking scat
# Checking lo
# Checking stock
# Checking b
# Checking bluffes
# Checking un
# Checking Jo
# Checking repen
# Checking astronom
# Checking viol
# Checking jackknife
# Checking g
# Checking fi
# Checking bunku
# Checking scr
# Checking Debb
# Checking r
# Checking bl
# Checking slave
# Checking out
# Checking f
# Checking vo
# Checking c
# Checking locku
# Checking schola
# Checking Gra
# Checking exten
# Checking ev
# Checking esthete
# Checking ro
# Checking fun
# Checking lectu
# Checking Klingo
# Checking Tancre
# Checking fr
# Checking chapar
# Checking coagu
# Checking Cra
# Checking tailcoa
# Checking dia
# Checking Accentur
# Checking Tegucigalpa'
# Checking hip
# Checking Russel
# Checking ha
# Checking syn
# Checking grandfat
# Checking stenc
# Checking S
# Checking St
# Checking trudge
# Checking film
# Checking naught
# Checking sea
# Checking Lati
# Checking gon
# Checking Nazii
# Checking Cochaba
# Checking subjugatio
# Checking justificati
# Checking HQ
# Checking superh
# Checking Yea
# Checking s
# Checking te
# Checking diki
# Checking S
# Checking sagg
# Checking espou
# Checking over
# Checking side
# Checking sh
# Checking Darlen
# Checking Ha
# Checking silence
# Checking Monr
# Checking g
# Checking Marx'
# Checking pimie
# Checking sc
# Checking sh
# Checking M
# Checking Hanfor
# Checking collocati
# Checking Maui'
# Checking aneurysm
# Checking scandalo
# Checking loo
# Checking ba
# Checking Nann
# Checking si
# Checking pa
# Checking Republ
# Checking belli
# Checking cas
# Checking comm
# Checking Harl
# Checking co
# Checking d
# Checking F
# Checking flos
# Checking c
# Checking Ram
# Checking ret
# Checking outlive
# Checking covenant
# Checking exa
# Checking Mar
# Checking Gordim
# Checking lake
# Checking FH
# Checking castigati
# Checking assass
# Checking enl
# Checking Altipla
# Checking Garrick'
# Checking Le
# Checking posterit
# Checking ba
# Checking equilib
# Checking tough
# Checking genocide
# Checking unaff
# Checking consci
# Checking participa
# Checking thr
# Checking road
# Checking po
# Checking Montgomer
# Checking interroga
# Checking br
# Checking smot
# Checking liqu
# Checking glyc
# Checking s
# Checking gues
# Checking Br
# Checking contusi
# Checking Jo
# Checking bluebel
# Checking adr
# Checking technical
# Checking speedboa
# Checking wher
# Checking Kr
# Checking c
# Checking signif
# Checking C
# Checking gri
# Checking handle
# Checking pulley
# Checking leuk
# Checking micro
# Checking overbal
# Checking sli
# Checking Ijs
# Checking te
# Checking riv
# Checking f
# Checking l
# Checking spaciousne
# Checking vibrato
# Checking cy
# Checking brusque
# Checking y'a
# Checking Kathl
# Checking j
# Checking lazybones
# Checking slalom
# Checking An
# Checking mouser
# Checking decontamina
# Checking bo
# Checking butter
# Checking un
# Checking s
# Checking T
# Checking Vi
# Checking inci
# Checking un
# Checking ca
# Checking timepiece
# Checking s
# Checking fli
# Checking s
# Checking replicato
# Checking R
# Checking au
# Checking rea
# Checking s
# Checking jur
# Checking bus
# Checking c
# Checking gher
# Checking cacophonie
# Checking u
# Checking dizzie
# Checking br
# Checking d
# Checking expositi
# Checking pr
# Checking d
# Checking Decca'
# Checking Parn
# Checking h
# Checking porta
# Checking m
# Checking ab
# Checking engagem
# Checking la
# Checking cas
# Checking Mus
# Checking infer
# Checking show
# Checking Iraq
# Checking statuett
# Checking millepede
# Checking brandish
# Checking spu
# Checking B
# Checking f
# Checking dealer
# Checking emba
# Checking di
# Checking stingra
# Checking nonparei
# Checking zwi
# Checking Ol
# Checking c
# Checking Semiram
# Checking c
# Checking le
# Checking Algi
# Checking secessionis
# Checking Carlen
# Checking o
# Checking Ta
# Checking Gul
# Checking L
# Checking interchangea
# Checking clamb
# Checking werewolv
# Checking fiscal
# Checking swindl
# Checking conf
# Checking blackberry
# Checking platfo
# Checking f
# Checking ca
# Checking Ma
# Checking pedicu
# Checking lispi
# Checking to
# Checking ha
# Checking seaso
# Checking vehic
# Checking qua
# Checking stag
# Checking reddene
# Checking lite
# Checking gl
# Checking regici
# Checking Cont
# Checking wi
# Checking p
# Checking h
# Checking nominat
# Checking dizzies
# Checking gu
# Checking evinc
# Checking gi
# Checking spare
# Checking lif
# Checking si
# Checking Duf
# Checking postc
# Checking sa
# Checking mammogra
# Checking c
# Checking sa
# Checking goo
# Checking canard'
# Checking sn
# Checking sin
# Checking curlicue'
# Checking adv
# Checking Bene
# Checking ta
# Checking flo
# Checking corpse'
# Checking gal
# Checking Ada
# Checking ayato
# Checking Marjo
# Checking academ
# Checking igua
# Checking c
# Checking ep
# Checking c
# Checking insig
# Checking batteni
# Checking selfles
# Checking restle
# Checking preposition
# Checking fricassee'
# Checking Me
# Checking cut
# Checking Alphonse'
# Checking Finni
# Checking v
# Checking cat
# Checking b
# Checking hu
# Checking combi
# Checking di
# Checking backre
# Checking Co
# Checking legi
# Checking shirtsle
# Checking Farsi'
# Checking pe
# Checking indis
# Checking sp
# Checking exha
# Checking J
# Checking motle
# Checking saddleb
# Checking moo
# Checking disengag
# Checking mang
# Checking restu
# Checking corti
# Checking c
# Checking yea
# Checking Delmar
# Checking carja
# Checking br
# Checking c
# Checking hig
# Checking movab
# Checking Tantalu
# Checking o
# Checking gam
# Checking contra
# Checking repriev
# Checking Chun
# Checking s
# Checking Toni
# Checking R
# Checking shortl
# Checking Jo
# Checking vas
# Checking V
# Checking beso
# Checking su
# Checking tireso
# Checking repriman
# Checking assist
# Checking cop
# Checking dex
# Checking fluff
# Checking congratulat
# Checking mutua
# Checking van
# Checking s
# Checking groo
# Checking retort
# Checking Zionis
# Checking circumspecti
# Checking par
# Checking ince
# Checking A
# Checking ba
# Checking conceptualiz
# Checking r
# Checking Dick
# Checking free
# Checking rec
# Checking wholesomen
# Checking bri
# Checking psych
# Checking coife
# Checking Co
# Checking sandcast
# Checking muc
# Checking interpret
# Checking pu
# Checking mi
# Checking sagac
# Checking e
# Checking ha
# Checking numbl
# Checking tra
# Checking Wikipe
# Checking misbeg
# Checking Th
# Checking unders
# Checking ru
# Checking purs
# Checking la
# Checking billfol
# Checking Sikh'
# Checking pitchman
# Checking sn
# Checking leg
# Checking stranglehold
# Checking outstat
# Checking smalli
# Checking milks
# Checking briber
# Checking imputat
# Checking ti
# Checking tyrannic
# Checking disea
# Checking vesic
# Checking reiss
# Checking anticipat
# Checking A
# Checking brainwash
# Checking Keish
# Checking arist
# Checking pacifi
# Checking g
# Checking int
# Checking d
# Checking hic
# Checking hypn
# Checking bias'
# Checking sta
# Checking effer
# Checking minera
# Checking snu
# Checking Gu
# Checking p
# Checking i
# Checking sw
# Checking insurge
# Checking farro
# Checking vaunt
# Checking whetst
# Checking Newt
# Checking creat
# Checking cooper
# Checking mans
# Checking Hercul
# Checking wir
# Checking ho
# Checking Lag
# Checking sand
# Checking dela
# Checking Brati
# Checking vapo
# Checking st
# Checking k
# Checking s
# Checking lowd
# Checking bi
# Checking vocal
# Checking fetin
# Checking L
# Checking trum
# Checking Attuck
# Checking unk
# Checking tendonitis
# Checking optimi
# Checking ma
# Checking fa
# Checking calve
# Checking hap
# Checking e
# Checking over'
# Checking came
# Checking updraft
# Checking to
# Checking yoghur
# Checking redden
# Checking refrigeran
# Checking via
# Checking s
# Checking sm
# Checking experimen
# Checking airfoi
# Checking Calv
# Checking t
# Checking pinio
# Checking Sassoon'
# Checking flo
# Checking mo
# Checking quadruplet'
# Checking f
# Checking Beth'
# Checking req
# Checking scal
# Checking tea
# Checking di
# Checking tro
# Checking cream'
# Checking extin
# Checking fertilize
# Checking motiv
# Checking n
# Checking Roosev
# Checking may
# Checking Nikki'
# Checking ch
# Checking po
# Checking o
# Checking g
# Checking printe
# Checking j
# Checking Rei
# Checking utt
# Checking shuffli
# Checking awak
# Checking go'
# Checking ax
# Checking Redgrave
# Checking flatte
# Checking chee
# Checking E
# Checking nuan
# Checking slo
# Checking beautif
# Checking Kansan'
# Checking car
# Checking na
# Checking Eucha
# Checking scoreles
# Checking disposition
# Checking pond
# Checking appendice
# Checking stabilizati
# Checking hou
# Checking disinte
# Checking chastel
# Checking overs
# Checking epoxie
# Checking c
# Checking presumi
# Checking grap
# Checking impriso
# Checking no
# Checking fasci
# Checking overra
# Checking kaleid
# Checking immov
# Checking pres
# Checking griddl
# Checking ca
# Checking seedie
# Checking hy
# Checking overch
# Checking cy
# Checking phlebi
# Checking vinta
# Checking narrowne
# Checking cou
# Checking Bridge
# Checking call
# Checking dodde
# Checking R
# Checking Zuko
# Checking Li
# Checking co
# Checking enligh
# Checking v
# Checking sieve
# Checking Shau
# Checking hoodoo
# Checking distressingl
# Checking airfiel
# Checking Glen
# Checking counterattac
# Checking I
# Checking spind
# Checking painst
# Checking dermati
# Checking sw
# Checking Ol
# Checking factionalis
# Checking d
# Checking Battl
# Checking m
# Checking L
# Checking muste
# Checking huntre
# Checking sie
# Checking deflect
# Checking o
# Checking fence
# Checking pacifist'
# Checking te
# Checking ringsid
# Checking for
# Checking galva
# Checking Jeff
# Checking Parsifal'
# Checking Hieronymu
# Checking romantical
# Checking Laverne'
# Checking significatio
# Checking washbo
# Checking s
# Checking n
# Checking at
# Checking m
# Checking s
# Checking compatib
# Checking sp
# Checking a
# Checking bilingu
# Checking im
# Checking studio
# Checking chole
# Checking Cam
# Checking s
# Checking rel
# Checking parry
# Checking pene
# Checking exce
# Checking s
# Checking subornation
# Checking s
# Checking gangl
# Checking binding
# Checking visualize
# Checking moa
# Checking le
# Checking cu
# Checking orc
# Checking hemsti
# Checking Manson
# Checking Kha
# Checking firefl
# Checking Pas
# Checking Senio
# Checking r
# Checking j
# Checking r
# Checking e
# Checking overrat
# Checking rati
# Checking p
# Checking transp
# Checking hairin
# Checking Blavats
# Checking co
# Checking fetishis
# Checking f
# Checking P
# Checking h
# Checking d
# Checking S
# Checking dir
# Checking cuis
# Checking free
# Checking reem
# Checking ros
# Checking Khoisa
# Checking bloc
# Checking sc
# Checking info
# Checking Cu
# Checking c
# Checking d
# Checking We
# Checking heis
# Checking acquai
# Checking d
# Checking healthies
# Checking incu
# Checking su
# Checking a
# Checking recru
# Checking comfort
# Checking Ghani
# Checking Norwich'
# Checking mazurka
# Checking overaw
# Checking prejudgmen
# Checking Ma
# Checking ca
# Checking madho
# Checking straightf
# Checking d
# Checking pub
# Checking ar
# Checking vertica
# Checking a
# Checking Cl
# Checking ela
# Checking carewo
# Checking head
# Checking reenfo
# Checking leade
# Checking forew
# Checking bat
# Checking likel
# Checking federati
# Checking criti
# Checking motorbik
# Checking puri
# Checking disaffec
# Checking ref
# Checking h
# Checking f
# Checking Irishw
# Checking bl
# Checking c
# Checking Ru
# Checking Lisb
# Checking worthlessness'
# Checking glycoge
# Checking pollin
# Checking slay
# Checking novitia
# Checking p
# Checking C
# Checking spa
# Checking mys
# Checking jou
# Checking s
# Checking devi
# Checking Ru
# Checking contrave
# Checking Ha
# Checking pr
# Checking caddy
# Checking sauciness'
# Checking cartridge'
# Checking glarin
# Checking Et
# Checking chirop
# Checking Je
# Checking ensn
# Checking st
# Checking ear
# Checking Tokuga
# Checking guil
# Checking Le
# Checking disgu
# Checking vi
# Checking r
# Checking g
# Checking orang
# Checking du
# Checking a
# Checking rec
# Checking stag
# Checking enclo
# Checking rom
# Checking stew
# Checking T
# Checking culmination'
# Checking ukul
# Checking harness
# Checking nota
# Checking su
# Checking counterrevol
# Checking s
# Checking str
# Checking u
# Checking bur
# Checking hardheart
# Checking Stei
# Checking cont
# Checking frescoe
# Checking med
# Checking k
# Checking unmistak
# Checking ch
# Checking stym
# Checking C
# Checking ba
# Checking catac
# Checking adum
# Checking Hummer'
# Checking Co
# Checking cannonade
# Checking rejoi
# Checking Lu
# Checking waddl
# Checking parity
# Checking Hispa
# Checking windsur
# Checking vocal
# Checking dynamite
# Checking k
# Checking oxyace
# Checking e
# Checking ring
# Checking deb
# Checking Mormon
# Checking fou
# Checking sch
# Checking gaffi
# Checking su
# Checking sub
# Checking dietitia
# Checking rec
# Checking conjoine
# Checking weddi
# Checking m
# Checking grubstak
# Checking keyno
# Checking in
# Checking dismis
# Checking l
# Checking Grundy'
# Checking burs
# Checking flexibil
# Checking parente
# Checking cordial
# Checking mar
# Checking t
# Checking autograp
# Checking das
# Checking bulg
# Checking thatchin
# Checking wholesa
# Checking fairness'
# Checking i
# Checking rais
# Checking chlo
# Checking bibliogra
# Checking doomin
# Checking n
# Checking Urals
# Checking T
# Checking Wi
# Checking mi
# Checking dessert
# Checking cir
# Checking lit
# Checking huss
# Checking nov
# Checking unle
# Checking Blonde
# Checking pro
# Checking condesce
# Checking dankl
# Checking Et
# Checking breast

# %% [markdown]
# # Levestein

# %%
import textdistance

# %%
retrieve_levestein_dist = textdistance.levenshtein

# %%
def levestein(text, max_dist):
    output = []
    for word in words:
        dist = retrieve_levestein_dist(word, text)
        if dist <= max_dist:
            output.append(word)
    return output

def get_cpp_levestein_results(text: str, dist: int):
    os.chdir("bin")
    program_path = './levestein'
    arguments = [text, str(dist)]
    subprocess.run([program_path] + arguments, text=True, capture_output=True)
    with open("../output_files/output_levestein.txt", 'r') as f:
        result = [x.replace('\n', '') for x in f.readlines()]
    result.sort()
    os.chdir("..")
    return result

def check_levestein(text, dist):
    return get_cpp_levestein_results(text, dist) == levestein(text, dist)

# %%
get_cpp_levestein_results("AAA", 1)
# Out:
# ['AA', 'AAA', 'AMA', 'FAA']

# %%
levestein("AAA", 1)
# Out:
# ['AA', 'AAA', 'AMA', 'FAA']

# %%
check_levestein("AAA", 1)
# Out:
# True

# %%
# [delete , add, replace, maintain]
maintain = 0.9
others = (1 - maintain)/3
porcentages = [others, others, others, maintain]
assert sum(porcentages) == 1
accumulated = 0
intervals = []
for porcentage in porcentages:
    accumulated += porcentage
    intervals.append(accumulated)

# %%
def get_action(number: float):
    output = 0
    while number > intervals[output]:
        output += 1
    return output

# %%
num_samples = 10

# %%
words_levestein = []
originals = []
for word in random.sample(words, num_samples):
    curr_word = ""
    curr_char_idx = 0
    while curr_char_idx != len(word):
        action = get_action(random.uniform(0, 1))
        # Delete char
        if action == 0:
            curr_char_idx += 1
        # Add random char
        elif action == 1:
            random_char = random.choice(string.ascii_letters)
            curr_word += random_char
        # Replace char
        elif action == 2:
            random_char = random.choice(string.ascii_letters)
            curr_word += random_char
            curr_char_idx += 1
        # Maintain char
        elif action == 3:
            curr_word += word[curr_char_idx]
            curr_char_idx += 1
    words_levestein.append(curr_word)
    originals.append(word)

# %%
index = 1
words_levestein[index], originals[index]
# Out:
# ("flLmflam's", "flimflam's")

# %%
errors = []
for word in words_levestein[:100]:
    print(f"Checking {word}")
    for dist in range(4):
        if not check_levestein(word, dist):
            print(f"Failed for {word} and {dist}")
            errors.append((word, dist))
# Out:
# Checking tcrunchbest
# Checking flLmflam's
# Checking Brvt's
# Checking readYness's
# Checking deZlphinium's
# Checking us's
# Checking glove
# Checking connctor
# Checking muttering
# Checking expdites
